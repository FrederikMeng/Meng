# %%
#yes or no questions
5>3
# Out:
# True

# %%
5<3
# Out:
# False

# %%
# == asks if 5 is 5
5==5
# Out:
# True

# %%
#asking python if 3 isn't equal to 5
3!=5
# Out:
# True

# %% [markdown]
# the data type (Bool) can have the values true or false

# %%
expression = 7 > 3
print (expression)

#this is a statement 7 > 3
# Out:
# True

# %%
exp1 = 5<6
print(exp1)
exp2 = 5+1 == 7
print(exp2)
print(type(exp2))
# Out:
# True
# False
# <class 'bool'>

# %%
#logical operators 
# not and or
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
 True or False
# Out:
# True

# %%
exp1 = 1 < 2 #true
exp2 = 1>5 #false
exp1 and exp2 #our way of asking if both our statements ae true
# Out:
# False

# %%
exp1 = 1<2 #tue
exp2 = 1< 5 #true
exp1 or exp2
# Out:
# True

# %%
p = True
q = False
#p and q  - false
#p or q - true
# not p - false
# not q -true
# (not p) and (not p) false
#(not p) or (not p) true

# %% [markdown]
# "or" if one or more is true
# "and" if both are true
# "not" true then it's false "not" false is true

# %% [markdown]
# #functions in python
# trype()
# print()
# int()
# float()
# str()
# bool()

# %%
#a way to regignize a function is by the 
mynumber =int("8")
#function takes input that is 8
#the data type "8" is int but because we write int() it converts it to an integer 
#so now the variable mynumber returns the value we assigned it wihch is 8

# %%
lettercount = len("hello") + len("world")
print(lettercount)
# Out:
# 10

# %% [markdown]
# Exercise 2

# %%
#task 1: using Python as a calculator
x = (3**(4-1) + ((16*(5**0-2))/2*4))
y = (x**2+(3-x)* x)
z =(y/x)

print(z)
# Out:
# 3.0

# %% [markdown]
# Task 2: Getting familiar with Booleans

# %%
True + True + True
# Out:
# 3

# %%
True * 7.5
# Out:
# 7.5

# %%
False + 9
# Out:
# 9

# %%
False - 5
# Out:
# -5

# %%
True / 4
# Out:
# 0.25

# %%
False * 40 # False has a value of 0
# Out:
# 0

# %%
False + False + False  # False has a value of 0
# Out:
# 0

# %%
bool(3>7) #Check if a statement is true
# Out:
# False

# %% [markdown]
# Task 3: Casting (converting) data types

# %%
### checking the type of an object
print (type(3))
print (type(1+2)) 
print (type(1+2.0))
print (type(9/3))
print (type("3"))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'float'>
# <class 'float'>
# <class 'str'>

# %%
print (str(1))
print (str(3.5))
print (str(True))
# Out:
# 1
# 3.5
# True

# %%
str(int(4.5))
# Out:
# '4'

# %% [markdown]
# Task 4: Combining strings
#
# A quick recap:
# You can use the + operator to concatenate strings
# You can use the * operator to "multiply" a string by an integer x, i.e. to repeat it x times
# If you want to concatena

# %%
a = "misc"
b = "ellane"
c = "ous"
# concatenate the variables a, b and c to obtain the word "miscellaneous" printed out

print(a+b+c)
# Out:
# miscellaneous

# %%
x = "i am" 
y = "very"
z = "angry"
# concatenate / multiply the variables x, y and to obtain the sentence "i am very very very very angry". 
# insert spaces if needed (within the variable definition, or like so: " ")

print(x+(" "+ y +" ")*4+z)
# Out:
# i am very  very  very  very angry

# %%
myint = 1
mybool = True
mystr = "Love"
# combine the variables myint, mybool and mystr to obtain the string "1 True Love". Add white spaces if needed.
print(str(myint)+ str(" ")+ str(mybool)+ str(" ") + (mystr))
# Out:
# 1 True Love

# %% [markdown]
# Task 5
# First, read the code below and try to predict what the output of each statement will be (either True or False); then implement it to check if you were correct.

# %%
#You are given three Boolean variables: Logical operators
p = True
q = False
r = True

prop1 = p and q  #False
print(prop1)

prop2 = p or q #true
print(prop2)

prop3 = p and not q #true
print(prop3)

prop4 = (not p) or (not q) #True
print(prop4)

prop5 = (p and q) or (not p and q) or (p or q) #true 
#.      (statement  is  false.   )    (true. )   
# so the whole statement false or false or true
print(prop5)

prop6 = p and q and r #False
print(prop6)

prop7 = (p and q) or r #True
print(prop7)

prop8 = p and (q or r) #True
print(prop8)

prop9 = (not p or q) or (not p or r) #True
print(prop9)

prop10 = (p and r) and (not q) and (q or r)#True
print(prop10)
# Out:
# False
# True
# True
# True
# True
# False
# True
# True
# True
# True
